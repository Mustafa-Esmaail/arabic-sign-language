# %%
import tensorflow as tf
import sys
import os
import numpy as np
import copy
import cv2

# install: pip install --upgrade arabic-reshaper
import arabic_reshaper

# install: pip install python-bidi
from bidi.algorithm import get_display


from PIL import ImageFont
from PIL import Image
from PIL import ImageDraw

# %%
model = tf.keras.models.load_model(filepath='sign-lang-ar.h5', compile=False)
cap = cv2.VideoCapture(0)

def process_image(img):

    img = cv2.resize(img, (64, 64))
    img = np.array(img, dtype=np.float32)
    img = np.reshape(img, (-1, 64 , 64 , 3))
    img = img.astype('float32') / 255.
    return img

# %%
frame_counter = 0

sequence = ''
fontFile = "fonts/Sahel.ttf"
font = ImageFont.truetype(fontFile, 70)
classesNames=['ain', 'al', 'aleff','bb','dal','dha','dhad','fa','gaaf','ghain','ha','haa','jeem','kaaf','khaa','la','laam',
        'meem','nun','ra','saad','seen','sheen','ta','taa','thaa','thal','toot','waw','ya','yaa','zay']

# %%
cap
# Out:
# < cv2.VideoCapture 00000178A44D1FB0>

# %%
imageTest=cv2.imread('1_21_M_al_4.jpg')
# cv2.imshow('img',imageTest)
proba = model.predict(process_image(imageTest))[0]
mx = np.argmax(proba)
score = proba[mx] * 100
res = classesNames[mx]
sequence = classesNames[mx]
print(mx)
print(proba)
print(classesNames[mx])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1
# [1.6619219e-12 9.9999285e-01 7.0320345e-19 1.3363620e-09 3.0577023e-17
#  1.1172870e-11 1.2431400e-15 2.8264918e-15 6.1286581e-14 1.7763236e-18
#  1.8789017e-09 3.1324012e-16 5.3371821e-16 2.2179667e-12 1.5877407e-21
#  6.1265093e-10 2.4251892e-13 1.7403111e-12 2.8274810e-17 2.2284689e-17
#  3.0013314e-24 1.2470686e-14 6.9649445e-06 2.2983208e-07 3.0578975e-19
#  1.1484541e-15 8.6729029e-13 2.4038898e-13 1.2296685e-17 1.5696216e-08
#  4.2636186e-10 8.5636522e-14]
# al

# %%
while True:
    ret, img = cap.read()
    img = cv2.flip(img, 1)
    
    if ret:
        x1, y1, x2, y2 = 0, 0, 700, 700
        img_cropped = img[y1:y2, x1:x2]

        
        
        a = cv2.waitKey(1)
        if frame_counter % 5 == 0:
            score = 0
            res = ''
            try:
                proba = model.predict(process_image(img))[0]
                mx = np.argmax(proba)
                score = proba[mx] * 100
                res = classesNames[mx]
                sequence = classesNames[mx]
            except:
                continue 

        reshaped_text = arabic_reshaper.reshape(sequence)   
        bidi_text = get_display(reshaped_text)    

        frame_counter += 1
        img_pil = Image.fromarray(img)
        draw = ImageDraw.Draw(img_pil)
        draw.text((50, 500), bidi_text, (255,255,255), font=font)
        img = np.array(img_pil)
        cv2.putText(img, '%s' % (res.upper()), (50,300), cv2.FONT_HERSHEY_SIMPLEX, 4, (122,0,0), 4)
        cv2.putText(img, '(score = %.5f)' % (float(score)), (100,450), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255))
        cv2.rectangle(img, (x1, y1), (x2, y2), (255,0,0), 2)
        cv2.imshow("img", img)

        
        if a == 27: # when `esc` is pressed
            break

# Following line should... <-- This should work fine now
cv2.destroyAllWindows() 
cv2.VideoCapture(0).release()
# Out:
# ...
# 1/1 [==============================] - 0s 33ms/step
# ...
# ...
# 1/1 [==============================] - 0s 35ms/step
